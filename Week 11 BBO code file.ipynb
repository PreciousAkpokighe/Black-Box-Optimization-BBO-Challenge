# %%
# ============================================================
# WEEK 11 BBO NOTEBOOK
# Clustering-Based Optimisation Strategy
# Week 1–10 inputs and outputs embedded directly
# ============================================================

import numpy as np
import warnings
from sklearn.cluster import KMeans
from sklearn.ensemble import RandomForestRegressor

warnings.filterwarnings("ignore")
np.random.seed(42)

# ============================================================
# WEEK 1–10 INPUT DATA
# ============================================================

inputs_by_week = [
    [
        np.array([0.211325, 0.788675]),
        np.array([0.723607, 0.276393]),
        np.array([0.166667, 0.500000, 0.833333]),
        np.array([0.125000, 0.375000, 0.625000, 0.875000]),
        np.array([0.875000, 0.625000, 0.375000, 0.125000]),
        np.array([0.150000, 0.350000, 0.550000, 0.750000, 0.950000]),
        np.array([0.900000, 0.100000, 0.700000, 0.300000, 0.500000, 0.800000]),
        np.array([0.111111, 0.222222, 0.333333, 0.444444, 0.555555, 0.666667, 0.777778, 0.888889])
    ],
    [
        np.array([0.654299, 0.353479]),
        np.array([0.754299, 0.253479]),
        np.array([0.304299, 0.553479, 0.709691]),
        np.array([0.804299, 0.603479, 0.409691, 0.205016]),
        np.array([0.854299, 0.653479, 0.359691, 0.155016]),
        np.array([0.904299, 0.703479, 0.509691, 0.305016, 0.103275]),
        np.array([0.884299, 0.123479, 0.729691, 0.285016, 0.523275, 0.787492]),
        np.array([0.104299, 0.243479, 0.319691, 0.465016, 0.573275, 0.647492, 0.794889, 0.860861])
    ],
    [
        np.array([0.582812, 0.421077]),
        np.array([0.712865, 0.284413]),
        np.array([0.118496, 0.481282, 0.876608]),
        np.array([1.000000, 0.683447, 0.334333, 0.000000]),
        np.array([0.882245, 0.615032, 0.380358, 0.114494]),
        np.array([0.000000, 0.226282, 0.564108, 0.905744, 1.000000]),
        np.array([0.905495, 0.091782, 0.689608, 0.305244, 0.491854, 0.804378]),
        np.array([0.113495, 0.214782, 0.338108, 0.437244, 0.549353, 0.673378, 0.771789, 0.898699])
    ],
    [
        np.array([0.183704, 0.127166]),
        np.array([0.255353, 0.749841]),
        np.array([0.094906, 0.770362, 0.859589]),
        np.array([0.820856, 0.226975, 0.784625, 0.113609]),
        np.array([0.917860, 0.273128, 0.475575, 0.052446]),
        np.array([0.052509, 0.789636, 0.354234, 0.228337, 0.889991]),
        np.array([0.833796, 0.096195, 0.232612, 0.789158, 0.185769, 0.681185]),
        np.array([0.448564, 0.335191, 0.751694, 0.277261, 0.167614, 0.717472, 0.304117, 0.767059])
    ],
    [
        np.array([0.582812, 0.421077]),
        np.array([0.684812, 0.281383]),
        np.array([0.171685, 0.508728, 0.819757]),
        np.array([0.734042, 0.687625, 0.466427, 0.303264]),
        np.array([0.568707, 0.909615, 0.957143, 0.011420]),
        np.array([0.744968, 0.084644, 0.801527, 0.169728, 0.990511]),
        np.array([1.000000, 0.229371, 0.690054, 0.244152, 0.521424, 1.000000]),
        np.array([0.022620, 0.000000, 0.288709, 0.762817, 0.551656, 0.961269, 0.843087, 1.000000])
    ],
    [
        np.array([0.582812, 0.421077]),
        np.array([0.996744, 0.999561]),
        np.array([0.166667, 0.500000, 0.833333]),
        np.array([0.743137, 0.718436, 0.581810, 0.365984]),
        np.array([0.572707, 0.914615, 0.952143, 0.016420]),
        np.array([0.236209, 0.379873, 0.584786, 0.843391, 1.000000]),
        np.array([0.024461, 0.059677, 0.995330, 0.299568, 0.038576, 0.691027]),
        np.array([0.148189, 0.189483, 0.270757, 0.392507, 0.446351, 0.670593, 0.665417, 1.000000])
    ],
    [
        np.array([0.582812, 0.421077]),
        np.array([0.744767, 0.322712]),
        np.array([0.167431, 0.503246, 0.833129]),
        np.array([0.692844, 0.522126, 0.400511, 0.337375]),
        np.array([0.543363, 0.994173, 0.995000, 0.003824]),
        np.array([0.236209, 0.379873, 0.584786, 0.843391, 1.000000]),
        np.array([0.194327, 0.008117, 0.940397, 0.331469, 0.120428, 0.708672]),
        np.array([0.208946, 0.148993, 0.202639, 0.316908, 0.431312, 0.503474, 0.634079, 0.995000])
    ],
    [
        np.array([0.582812, 0.421077]),
        np.array([0.723607, 0.276393]),
        np.array([0.173580, 0.509985, 0.861627]),
        np.array([0.605953, 0.443908, 0.321881, 0.510101]),
        np.array([0.503541, 0.995000, 0.995000, 0.000001]),
        np.array([0.339419, 0.513193, 0.599128, 0.825009, 0.789136]),
        np.array([0.232309, 0.000001, 0.881882, 0.376082, 0.191527, 0.731904]),
        np.array([0.045850, 0.409304, 0.057579, 0.179582, 0.499647, 0.251108, 0.757574, 0.939082])
    ],
    [
        np.array([0.582812, 0.421077]),
        np.array([0.694340, 0.207302]),
        np.array([0.147117, 0.526235, 0.849011]),
        np.array([0.524137, 0.403433, 0.220030, 0.482874]),
        np.array([0.577252, 0.995000, 0.995000, 0.000001]),
        np.array([0.482662, 0.445135, 0.505979, 0.901513, 0.790255]),
        np.array([0.234062, 0.000001, 0.862390, 0.432759, 0.245568, 0.773410]),
        np.array([0.246667, 0.211931, 0.156108, 0.312021, 0.424946, 0.497662, 0.627877, 0.995000])
    ],
    [
        np.array([0.582812, 0.421077]),
        np.array([0.718442, 0.086744]),
        np.array([0.155756, 0.525144, 0.938413]),
        np.array([0.658829, 0.135745, 0.014750, 0.885838]),
        np.array([0.614625, 0.995000, 0.995000, 0.000001]),
        np.array([0.396866, 0.534494, 0.843367, 0.854385, 0.577951]),
        np.array([0.236193, 0.000001, 0.838386, 0.411651, 0.294881, 0.727030]),
        np.array([0.246667, 0.211931, 0.156108, 0.312021, 0.424946, 0.497662, 0.627877, 0.995000])
    ]
]

# ============================================================
# WEEK 1–10 OUTPUT DATA
# ============================================================

outputs_by_week = [
    np.array([1.1327056288856873e-125, 0.5675786892822564, -0.032385408076210126, -17.20744048260943, 60.223125, -1.3287857969718009, 0.34356041660314957, 9.0501517903694]),
    np.array([1.1867858443665185e-41, 0.2715258567299176, -0.1198581070659559, -13.082213230390916, 50.179390256321376, -1.5080002951000964, 0.31639485635485903, 9.0219949134074]),
    np.array([7.99676981308551e-19, 0.5213723465552891, -0.04726977098841539, -25.67625344929702, 64.78245026474816, -1.7372122723701597, 0.3507828450585503, 9.0587238074074]),
    np.array([-2.410121917336285e-100, 0.0244939290195959, -0.04207093453964322, -20.330739763644917, 61.278397876784794, -2.4624737429462145, 0.0634803557047261, 8.275283250689899]),
    np.array([7.99676981308551e-19, 0.4258127251524913, -0.06232295859499999, -12.496845976106417, 942.2521944777988, -2.280900502246122, 0.21828066675598462, 8.427686115001]),
    np.array([7.99676981308551e-19, -0.004122974640885927, -0.032385408076210126, -14.192389833871584, 943.6841142765069, -1.2257941580841207, 0.4410410448155631, 9.3346877420455]),
    np.array([7.99676981308551e-19, 0.3799297936947829, -0.03240117791304375, -6.92709780967855, 1723.425126888365, -1.2923495282910902, 0.919847131115406, 9.472143824862]),
    np.array([7.99676981308551e-19, 0.5381696913344642, -0.02792717356049581, -4.634066674167709, 1679.193994434957, -1.0832489053663208, 1.3511467710792968, 9.1699591109441]),
    np.array([7.99676981308551e-19, 0.5123530018001279, -0.025522227618805376, -4.5906554634204895, 1784.4636825839586, -1.153199093198391, 1.3736252613501883, 9.472748274068]),
    np.array([7.99676981308551e-19, 0.5380835457242255, -0.17435713522547233, -23.112309779047532, 1857.0401615205615, -0.9469472223006096, 1.6718981508700566, 9.472748274068])
]

# ============================================================
# CLUSTERING-BASED OPTIMISATION FUNCTIONS
# ============================================================

def get_history(function_index):
    X = np.vstack([week[function_index] for week in inputs_by_week])
    y = np.array([week[function_index] for week in outputs_by_week])
    return X, y


def choose_k(n):
    if n < 8:
        return 2
    if n < 12:
        return 3
    return 4


def cluster_history(X, y):
    k = choose_k(len(X))

    kmeans = KMeans(n_clusters=k, random_state=42, n_init=20)
    labels = kmeans.fit_predict(X)

    cluster_summary = {}

    for c in range(k):
        idx = labels == c
        cluster_summary[c] = {
            "count": int(idx.sum()),
            "mean_output": float(np.mean(y[idx])),
            "max_output": float(np.max(y[idx])),
            "centroid": np.mean(X[idx], axis=0)
        }

    best_cluster = max(cluster_summary, key=lambda c: cluster_summary[c]["mean_output"])
    worst_cluster = min(cluster_summary, key=lambda c: cluster_summary[c]["mean_output"])

    return labels, cluster_summary, best_cluster, worst_cluster


def generate_candidates(X, y, function_index, n_candidates=20000):
    labels, summary, best_cluster, worst_cluster = cluster_history(X, y)

    dim = X.shape[1]
    best_x = X[np.argmax(y)]
    best_centroid = summary[best_cluster]["centroid"]
    worst_centroid = summary[worst_cluster]["centroid"]

    if function_index == 4:
        local_radius = 0.008
        centroid_radius = 0.015
        global_ratio = 0.03

    elif function_index in [2, 3, 5]:
        local_radius = 0.080
        centroid_radius = 0.110
        global_ratio = 0.28

    elif function_index in [6, 7]:
        local_radius = 0.030
        centroid_radius = 0.055
        global_ratio = 0.10

    else:
        local_radius = 0.050
        centroid_radius = 0.080
        global_ratio = 0.18

    # Safe candidate allocation
    n_global = int(n_candidates * global_ratio)
    n_local = int(n_candidates * 0.35)
    n_cluster = int(n_candidates * 0.30)

    n_interp = n_candidates - n_global - n_local - n_cluster

    # Safety check
    if n_interp < 0:
        n_interp = max(500, int(n_candidates * 0.10))

    local_best = np.clip(
        best_x + np.random.normal(0, local_radius, size=(n_local, dim)),
        0.000001,
        0.995000
    )

    cluster_samples = np.clip(
        best_centroid + np.random.normal(0, centroid_radius, size=(n_cluster, dim)),
        0.000001,
        0.995000
    )

    mix = np.random.uniform(0.3, 1.0, size=(n_interp, 1))

    interp = np.clip(
        mix * best_x + (1 - mix) * best_centroid + np.random.normal(0, 0.020, size=(n_interp, dim)),
        0.000001,
        0.995000
    )

    global_search = np.random.uniform(
        0.000001,
        0.995000,
        size=(n_global, dim)
    )

    candidates = np.vstack([
        local_best,
        cluster_samples,
        interp,
        global_search,
        X
    ])

    # Avoid worst cluster
    dist_to_worst = np.linalg.norm(candidates - worst_centroid, axis=1)
    threshold = np.percentile(dist_to_worst, 20)
    candidates = candidates[dist_to_worst >= threshold]

    return candidates, summary, best_cluster, worst_cluster, best_x


def train_surrogate(X, y):
    model = RandomForestRegressor(
        n_estimators=600,
        max_depth=5,
        random_state=42
    )
    model.fit(X, y)
    return model


def propose_week11(function_index):
    X, y = get_history(function_index)

    candidates, summary, best_cluster, worst_cluster, best_x = generate_candidates(X, y, function_index)

    model = train_surrogate(X, y)
    preds = model.predict(candidates)

    distance = np.linalg.norm(candidates - best_x, axis=1)

    if function_index == 4:
        score = preds - 0.25 * distance
        strategy = "Exploit best cluster tightly because Function 5 remains the strongest."
    elif function_index in [2, 3, 5]:
        score = preds - 0.035 * distance
        strategy = "Explore wider while avoiding poor clusters because output is still negative."
    elif function_index in [6, 7]:
        score = preds - 0.080 * distance
        strategy = "Moderate exploitation around positive clusters."
    else:
        score = preds - 0.060 * distance
        strategy = "Balanced cluster-guided search."

    selected = candidates[np.argmax(score)]

    return (
        np.round(selected, 6),
        np.max(y),
        best_x,
        summary,
        best_cluster,
        worst_cluster,
        strategy,
        model.feature_importances_
    )


# ============================================================
# GENERATE WEEK 11 INPUTS
# ============================================================

week11_inputs = []

print("WEEK 11 CLUSTERING-BASED BBO INPUT GENERATION")
print("=============================================\n")

for function_index in range(8):
    candidate, best_output, best_input, summary, best_cluster, worst_cluster, strategy, importance = propose_week11(function_index)

    week11_inputs.append(candidate)

    print(f"Function {function_index + 1}")
    print(f"Best historical output: {best_output}")
    print(f"Best historical input:  {np.round(best_input, 6)}")
    print(f"Best cluster:           {best_cluster}")
    print(f"Worst cluster:          {worst_cluster}")
    print(f"Strategy:               {strategy}")
    print(f"Feature importance:     {np.round(importance, 4)}")
    print(f"Week 11 suggested input:{candidate}")
    print()

print("PORTAL-READY WEEK 11 INPUTS")
print("===========================\n")

for i, arr in enumerate(week11_inputs, start=1):
    formatted = "-".join(f"{x:.6f}" for x in arr)
    print(f"Function {i}: {formatted}")
# Out:
# WEEK 11 CLUSTERING-BASED BBO INPUT GENERATION
# =============================================
#
# Function 1
# Best historical output: 7.99676981308551e-19
# Best historical input:  [0.582812 0.421077]
# Best cluster:           1
# Worst cluster:          0
# Strategy:               Balanced cluster-guided search.
# Feature importance:     [0. 0.]
# Week 11 suggested input:[0.582812 0.421077]
#
# Function 2
# Best historical output: 0.5675786892822564
# Best historical input:  [0.723607 0.276393]
# Best cluster:           1
# Worst cluster:          2
# Strategy:               Balanced cluster-guided search.
# Feature importance:     [0.4305 0.5695]
# Week 11 suggested input:[0.723607 0.276393]
#
# Function 3
# Best historical output: -0.025522227618805376
# Best historical input:  [0.147117 0.526235 0.849011]
# Best cluster:           0
# Worst cluster:          2
# Strategy:               Explore wider while avoiding poor clusters because output is still negative.
# Feature importance:     [0.1963 0.1148 0.6889]
# Week 11 suggested input:[0.14903  0.507335 0.866594]
#
# Function 4
# Best historical output: -4.5906554634204895
# Best historical input:  [0.524137 0.403433 0.22003  0.482874]
# Best cluster:           1
# Worst cluster:          2
# Strategy:               Explore wider while avoiding poor clusters because output is still negative.
# Feature importance:     [0.2538 0.2309 0.2887 0.2265]
# Week 11 suggested input:[0.574526 0.455077 0.168845 0.479246]
#
# Function 5
# Best historical output: 1857.0401615205615
# Best historical input:  [6.14625e-01 9.95000e-01 9.95000e-01 1.00000e-06]
# Best cluster:           1
# Worst cluster:          2
# Strategy:               Exploit best cluster tightly because Function 5 remains the strongest.
# Feature importance:     [0.2414 0.2121 0.1983 0.3482]
# Week 11 suggested input:[6.14625e-01 9.95000e-01 9.95000e-01 1.00000e-06]
#
# Function 6
# Best historical output: -0.9469472223006096
# Best historical input:  [0.396866 0.534494 0.843367 0.854385 0.577951]
# Best cluster:           1
# Worst cluster:          2
# Strategy:               Explore wider while avoiding poor clusters because output is still negative.
# Feature importance:     [0.0976 0.2511 0.1134 0.4886 0.0493]
# Week 11 suggested input:[0.396866 0.534494 0.843367 0.854385 0.577951]
#
# Function 7
# Best historical output: 1.6718981508700566
# Best historical input:  [2.36193e-01 1.00000e-06 8.38386e-01 4.11651e-01 2.94881e-01 7.27030e-01]
# Best cluster:           1
# Worst cluster:          0
# Strategy:               Moderate exploitation around positive clusters.
# Feature importance:     [0.1048 0.5566 0.1185 0.1558 0.0246 0.0397]
# Week 11 suggested input:[2.36193e-01 1.00000e-06 8.38386e-01 4.11651e-01 2.94881e-01 7.27030e-01]
#
# Function 8
# Best historical output: 9.472748274068
# Best historical input:  [0.246667 0.211931 0.156108 0.312021 0.424946 0.497662 0.627877 0.995   ]
# Best cluster:           0
# Worst cluster:          2
# Strategy:               Moderate exploitation around positive clusters.
# Feature importance:     [0.1212 0.0741 0.0672 0.0556 0.0818 0.4133 0.0891 0.0979]
# Week 11 suggested input:[0.246667 0.211931 0.156108 0.312021 0.424946 0.497662 0.627877 0.995   ]
#
# PORTAL-READY WEEK 11 INPUTS
# ===========================
#
# Function 1: 0.582812-0.421077
# Function 2: 0.723607-0.276393
# Function 3: 0.149030-0.507335-0.866594
# Function 4: 0.574526-0.455077-0.168845-0.479246
# Function 5: 0.614625-0.995000-0.995000-0.000001
# Function 6: 0.396866-0.534494-0.843367-0.854385-0.577951
# Function 7: 0.236193-0.000001-0.838386-0.411651-0.294881-0.727030
# Function 8: 0.246667-0.211931-0.156108-0.312021-0.424946-0.497662-0.627877-0.995000
